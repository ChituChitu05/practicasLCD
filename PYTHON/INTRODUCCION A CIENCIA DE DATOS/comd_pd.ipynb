# %%
# !pip install pandas

# %%
import pandas as pd
df = pd.read_csv('empleados.csv')

df.ffill(inplace=True)

df.isnull().sum()
##ordenar de menor a mayor
df.sort_values(['Edad'])

## aplicar funcion  mezclazr
df['Edad'].apply(lambda  x: int(x)**2,)
##df.apply(lambda x: x**2)
# Out:
# 0       3364
# 1       2304
# 2       1156
# 3        729
# 4       1600
#         ...
# 1495    2704
# 1496     625
# 1497    1156
# 1498    2601
# 1499     900
# Name: Edad, Length: 1500, dtype: int64

# %%
import pandas as pd

df = pd.read_csv('archivo.csv')


df.sort_values(['Columna'])

df.apply(lambda x : x**2)

df.fillna(method = 'ffill')

df.drop_duplicates()

df.interpolate(method = 'lineal')

df['Columna'].agg(['mean', 'median', 'std'])

df1 = pd.read_excel('archivo.xslx')
df1['Nombre'].str.lower() 
df1['Nombre'].str.contains('Marco') 
df1['Nombre'].str.split(',').str[0] 
df1['Nombre'].str.strip()

# %%
import numpy as np
import pandas as pd

for i in range(30):
	# codigo
arreglo = np.array([1,2,5,7])
print(arreglo[2])

matriz = np.array([1,2,5], [-1,2,3], [0,1,2])


dim = len(arreglo)
dim_sh = arreglo.shape()
print(dim)


df  = read_csv("archivo.csv")

df.head(15)

df.tail(15)

df.info()

df.shape()

df.describe()
